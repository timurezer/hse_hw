# %%
import numpy as np
import seaborn as sns
import numpy.random as rd
import matplotlib.pyplot as plt
import math
from IPython.display import display, Math
import scipy.stats as st

# %% [markdown]
# Пусть $\xi_i \in \mathcal{NegBin}(r, p)$. Покажите, что при $r \to \inf$ негативно биномиальное распределение $NegBin(r, 1 - \frac{\lambda}{r+\lambda})$ стремится к распределению Пуассона $Pois(\lambda)$.
#
# Негативно биномиальное распределени --- количество неудач в серии ИБ с вероятностью $p$, произошедших до $r$-ого успеха.
#
# $$f(k) = \binom{k+r-1}{r-1}p^r(1-p)^k$$

# %%
cmap = plt.get_cmap("tab10").colors

plt.figure(figsize=(15, 15))

lam = 21

for k, r in enumerate([10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000]):
    p = 1 - lam / (lam + r)
    c = [st.nbinom.pmf(i, r, p) for i in range(30)]
    plt.subplot(3, 3, k+1)
    plt.tight_layout()
    y = [st.poisson.pmf(i, lam) for i in range(30)]
    plt.plot(list(range(30)), y, '.-', c='k', label="Poiss")
    plt.scatter(list(range(30)), c, marker='s', color=cmap[k], label="r = " + str(r))
    #plt.xticks(x, x)
    plt.xlabel("k")
    plt.ylabel(r"$P(\xi _n=k)$")
    plt.legend()
plt.show()

# %%
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
x = st.norm.rvs(size=1000)
# по дефолту используется ф-ла Стерджесса (но в старых версиях, кажется, было дефолтное 10)
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(x)
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# мало - плохо, ничего не видно
sns.histplot(x, bins=5)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# много - тоже плохо, слишком много шума, общей картины не видно
sns.histplot(x, bins=150)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# можно поменять способ выбора количества бинов. более подробно тут https://numpy.org/doc/stable/reference/generated/numpy.histogram_bin_edges.html#numpy.histogram_bin_edges
sns.histplot(x, bins='rice')
# Out:
# <AxesSubplot:ylabel='Count'>
